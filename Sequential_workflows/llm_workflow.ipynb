# %%
from langgraph.graph import StateGraph , START ,END
from typing import TypedDict
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

# %%
load_dotenv()

model = ChatOpenAI()

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

#create nodes
graph.add_node('create_outline' , create_outline)
graph.add_node('create_blog', create_blog)

#create edges
graph.add_edge(START ,'create_outline')
graph.add_edge('create_outline' ,'create_blog')
graph.add_edge('create_blog' ,END)

workflow =graph.compile()

# %%
initial_state ={'title' : 'Where is latur city'}

final_state = workflow.invoke(initial_state)

final_state['content']
# Out:
# "Latur city is a hidden gem located in the Indian state of Maharashtra. This city has a rich history, vibrant culture, and stunning natural beauty that make it a must-visit destination for travelers. In this blog, we will explore the history, geographical location, attractions, importance, and challenges faced by Latur city.\n\nHistory of Latur city\nLatur city was founded in the 16th century and has since played a significant role in the history of Maharashtra. It has been ruled by various dynasties such as the Rashtrakutas, Yadavas, and the Bahmani Sultanate. Latur city has a strong cultural heritage and is known for its architectural marvels and historical sites.\n\nGeographical location of Latur city\nLatur city is located in the Marathwada region of Maharashtra. It is situated in the southeastern part of the state and is bordered by Osmanabad, Beed, Nanded, and Parbhani districts. The city has a semi-arid climate with hot summers and mild winters. The topography of Latur city is characterized by rolling hills, fertile plains, and rich vegetation.\n\nHow to reach Latur city\nLatur city is well-connected by air, rail, and road. The nearest airport is in Nanded, which is approximately 100 kilometers away from Latur. The city is also served by a major railway station that connects it to various parts of Maharashtra and neighboring states. There are regular bus services and private taxis available for travel within the city.\n\nAttractions in Latur city\nLatur city is home to numerous historical landmarks, cultural sites, and natural attractions. Some of the must-visit places include Siddheshwar Temple, Udgir Fort, Ashtvinayak Temple, Shirur Anantpal, and Wadwal Nagnath Temple. The city also offers a vibrant shopping and dining experience with bustling markets and delicious local cuisine.\n\nImportance of Latur city\nLatur city holds immense economic significance due to its thriving agriculture and industrial sectors. It is also a popular tourist destination with its historical sites, cultural festivals, and warm hospitality. The city plays a crucial role in the overall development of the Marathwada region and contributes to the state's tourism industry.\n\nChallenges faced by Latur city\nDespite its many attractions, Latur city faces various challenges such as inadequate infrastructure, environmental degradation, socio-economic issues, and lack of resources. The government has been implementing initiatives to address these challenges and promote sustainable development in the city.\n\nIn conclusion, knowing the location and significance of Latur city is essential for travelers looking to explore the beauty of Maharashtra. This city offers a unique blend of history, culture, and nature that is sure to captivate visitors. I encourage all readers to visit Latur city and immerse themselves in its rich heritage and vibrant atmosphere."
